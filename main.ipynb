# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git config --global user.email "cy991130@gmail.com"
# !git config --global user.name "changyi"

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
# !git add -A
# !git commit -m "first commit"
# Out:
# [master (root-commit) f73ff62] first commit
#  9 files changed, 2884 insertions(+)
#  create mode 100644 12 05 B0744118 .ipynb
#  create mode 100644 12 05 pythonworkshop.ipynb
#  create mode 100644 20201123.pdf
#  create mode 100644 B0744118
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 main.ipynb
#  create mode 100644 python_workshop_20201205/Cdata.csv
#  create mode 100644 python_workshop_20201205/DatasaurusDozen.tsv
#  create mode 100644 python_workshop_20201205/WHO_COVID-19.csv
